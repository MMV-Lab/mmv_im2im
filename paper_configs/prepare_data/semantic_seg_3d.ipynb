# %%
import pandas as pd
import quilt3
from pathlib import Path
from aicsimageio import AICSImage
from aicsimageio.writers import OmeTiffWriter
from random import random
import numpy as np

# we use the NUP153 cell line for this demo
cline = "FBL"

# set up path
parent_path = Path("../../data/semantic3D")

raw_path = parent_path / Path("download")
raw_path.mkdir(exist_ok=True)
train_path = parent_path / Path("train_fbl")
train_path.mkdir(exist_ok=True)
holdout_path = parent_path / Path("holdout_fbl")
holdout_path.mkdir(exist_ok=True)

# set up path
parent_path_2 = Path("../../data/instance3D")

raw_path_2 = parent_path_2 / Path("download")
raw_path_2.mkdir(exist_ok=True)
train_path_2 = parent_path_2 / Path("train_fbl")
train_path_2.mkdir(exist_ok=True)
holdout_path_2 = parent_path_2 / Path("holdout_fbl")
holdout_path_2.mkdir(exist_ok=True)

# %%
from skimage.morphology import remove_small_objects
from aicssegmentation.core.pre_processing_utils import (
    intensity_normalization,
    image_smoothing_gaussian_3d,
)
from aicssegmentation.core.seg_dot import dot_slice_by_slice

# %%
# connect to quilt and load meta table
pkg = quilt3.Package.browse(
    "aics/hipsc_single_cell_image_dataset", registry="s3://allencell"
)
meta_df_obj = pkg["metadata.csv"]
meta_df_obj.fetch(parent_path / "meta.csv")
meta_df = pd.read_csv(parent_path / "meta.csv")

# fetch the data of the specific cell line
meta_df_line = meta_df.query("structure_name==@cline")

# collapse the data table based on FOVId
meta_df_line.drop_duplicates(subset="FOVId", inplace=True)

# reset index
meta_df_line.reset_index(drop=True, inplace=True)
# Out:
# Loading manifest: 100%|██████████| 484465/484465 [00:12<00:00, 37.8k/s]
# 100%|██████████| 1.69G/1.69G [00:40<00:00, 41.8MB/s]
# /tmp/ipykernel_2059247/3370391117.py:7: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta_df = pd.read_csv(parent_path / "meta.csv")
# /tmp/ipykernel_2059247/3370391117.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   meta_df_line.drop_duplicates(subset="FOVId", inplace=True)

# %%
# download the images and segmentation
num_sample = 150
train_counter = 0
for row in meta_df_line.itertuples():
    if train_counter >= num_sample:
        break
    # fetch the raw image (multi-channel)
    subdir_name = row.fov_path.split("/")[0]
    file_name = row.fov_path.split("/")[1]

    local_fn = raw_path / f"{row.FOVId}_original.tiff"
    pkg[subdir_name][file_name].fetch(local_fn)

    # extract the fbl channel
    reader = AICSImage(local_fn)
    img = reader.get_image_data(
        "ZYX", C=row.ChannelNumberStruct, S=0, T=0
    )

    mean_intensity = img.mean() 
    if mean_intensity < 450 or mean_intensity > 500:
        continue

    if random() < 0.2:
        out_path = holdout_path
        out_path_2 = holdout_path_2
    else:
        out_path = train_path
        out_path_2 = train_path_2
        train_counter += 1

    # fetch cell segmentation
    subdir_name = row.fov_seg_path.split("/")[0]
    file_name = row.fov_seg_path.split("/")[1]

    local_fn = raw_path / f"{row.FOVId}_seg.tiff"
    pkg[subdir_name][file_name].fetch(local_fn)

    # extract the Cell segmentation
    reader = AICSImage(local_fn)
    cell_seg = reader.get_image_data(
        "ZYX", C=1, S=0, T=0
    ).astype(np.uint8)

    # generate structure segmentation
    struct_img = intensity_normalization(img.copy(), scaling_param=[0.5, 18])
    structure_img_smooth = image_smoothing_gaussian_3d(
        struct_img,
        sigma=1,
        truncate_range=3.0,
    )
    response2d = dot_slice_by_slice(structure_img_smooth, log_sigma=1)
    struct_seg = remove_small_objects(response2d > 0.01, min_size=5, connectivity=1)
    struct_seg = struct_seg.astype(np.uint8)
    struct_seg[struct_seg > 0] = 1

    struct_seg_label = struct_seg * cell_seg

    # save the data
    im_fn = out_path / f"{row.FOVId}_IM.tiff"
    gt_fn = out_path / f"{row.FOVId}_GT.tiff"
    OmeTiffWriter.save(img, im_fn, dim_order="ZYX")
    OmeTiffWriter.save(struct_seg, gt_fn, dim_order="ZYX")

    im_fn = out_path_2 / f"{row.FOVId}_IM.tiff"
    gt_fn = out_path_2 / f"{row.FOVId}_GT.tiff"
    OmeTiffWriter.save(img, im_fn, dim_order="ZYX")
    OmeTiffWriter.save(struct_seg_label, gt_fn, dim_order="ZYX")
# Out:
# 100%|██████████| 384M/384M [00:13<00:00, 28.0MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.67M/1.67M [00:04<00:00, 415kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 378M/378M [00:14<00:00, 25.8MB/s]
# 100%|██████████| 1.31M/1.31M [00:04<00:00, 325kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 379M/379M [00:15<00:00, 24.7MB/s]
# 100%|██████████| 1.69M/1.69M [00:03<00:00, 482kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 385M/385M [00:24<00:00, 16.0MB/s]
# 100%|██████████| 1.24M/1.24M [00:03<00:00, 354kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 378M/378M [00:14<00:00, 26.7MB/s]
# 100%|██████████| 1.46M/1.46M [00:03<00:00, 418kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 387M/387M [00:15<00:00, 24.9MB/s]
# 100%|██████████| 1.42M/1.42M [00:04<00:00, 338kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 374M/374M [00:16<00:00, 22.9MB/s]
# 100%|██████████| 1.17M/1.17M [00:03<00:00, 329kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 385M/385M [00:15<00:00, 25.2MB/s]
# 100%|██████████| 1.76M/1.76M [00:03<00:00, 500kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 385M/385M [00:16<00:00, 23.1MB/s]
# 100%|██████████| 381M/381M [00:20<00:00, 18.7MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.36M/1.36M [00:03<00:00, 391kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 391M/391M [00:14<00:00, 26.6MB/s]
# 100%|██████████| 377M/377M [00:10<00:00, 34.6MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.56M/1.56M [00:03<00:00, 448kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 384M/384M [00:14<00:00, 26.9MB/s]
# 100%|██████████| 1.81M/1.81M [00:03<00:00, 516kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 375M/375M [00:12<00:00, 29.5MB/s]
# 100%|██████████| 1.44M/1.44M [00:05<00:00, 246kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 379M/379M [00:18<00:00, 21.0MB/s]
# 100%|██████████| 1.64M/1.64M [00:04<00:00, 376kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 377M/377M [00:16<00:00, 23.5MB/s]
# 100%|██████████| 1.85M/1.85M [00:03<00:00, 532kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 376M/376M [00:17<00:00, 21.9MB/s]
# 100%|██████████| 1.76M/1.76M [00:03<00:00, 496kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 384M/384M [00:15<00:00, 24.1MB/s]
# 100%|██████████| 1.63M/1.63M [00:04<00:00, 401kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 385M/385M [00:15<00:00, 24.7MB/s]
# 100%|██████████| 1.62M/1.62M [00:03<00:00, 464kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 377M/377M [00:12<00:00, 31.2MB/s]
# 100%|██████████| 1.63M/1.63M [00:03<00:00, 464kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 376M/376M [00:19<00:00, 18.8MB/s]
# 100%|██████████| 1.65M/1.65M [00:03<00:00, 466kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 377M/377M [00:15<00:00, 23.6MB/s]
# 100%|██████████| 1.34M/1.34M [00:03<00:00, 381kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 375M/375M [00:19<00:00, 19.3MB/s]
# 100%|██████████| 1.54M/1.54M [00:03<00:00, 437kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 373M/373M [00:17<00:00, 21.2MB/s]
# 100%|██████████| 1.27M/1.27M [00:03<00:00, 361kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 380M/380M [00:15<00:00, 24.9MB/s]
# 100%|██████████| 1.62M/1.62M [00:03<00:00, 436kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 385M/385M [00:17<00:00, 22.2MB/s]
# 100%|██████████| 1.73M/1.73M [00:06<00:00, 272kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 384M/384M [00:14<00:00, 25.7MB/s]
# 100%|██████████| 1.95M/1.95M [00:03<00:00, 547kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 377M/377M [00:15<00:00, 24.9MB/s]
# 100%|██████████| 1.40M/1.40M [00:03<00:00, 396kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 381M/381M [00:17<00:00, 21.3MB/s]
# 100%|██████████| 1.64M/1.64M [00:03<00:00, 464kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 390M/390M [00:17<00:00, 23.0MB/s]
# 100%|██████████| 1.60M/1.60M [00:03<00:00, 452kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 392M/392M [00:19<00:00, 20.1MB/s]
# 100%|██████████| 1.73M/1.73M [00:03<00:00, 499kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 376M/376M [00:14<00:00, 26.8MB/s]
# 100%|██████████| 1.34M/1.34M [00:03<00:00, 385kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 391M/391M [00:16<00:00, 23.4MB/s]
# 100%|██████████| 384M/384M [00:15<00:00, 24.7MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.83M/1.83M [00:03<00:00, 521kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 379M/379M [00:15<00:00, 25.0MB/s]
# 100%|██████████| 1.84M/1.84M [00:03<00:00, 525kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 384M/384M [00:15<00:00, 24.6MB/s]
# 100%|██████████| 2.02M/2.02M [00:03<00:00, 551kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 406M/406M [00:12<00:00, 31.4MB/s]
# 100%|██████████| 1.70M/1.70M [00:03<00:00, 480kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 398M/398M [00:12<00:00, 30.9MB/s]
# 100%|██████████| 415M/415M [00:15<00:00, 26.4MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.54M/1.54M [00:03<00:00, 436kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 408M/408M [00:16<00:00, 24.9MB/s]
# 100%|██████████| 1.90M/1.90M [00:03<00:00, 552kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 399M/399M [00:14<00:00, 27.2MB/s]
# 100%|██████████| 1.11M/1.11M [00:03<00:00, 303kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 403M/403M [00:15<00:00, 26.8MB/s]
# 100%|██████████| 1.58M/1.58M [00:03<00:00, 453kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 404M/404M [00:14<00:00, 28.4MB/s]
# 100%|██████████| 1.64M/1.64M [00:03<00:00, 460kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 403M/403M [00:15<00:00, 25.8MB/s]
# 100%|██████████| 1.41M/1.41M [00:03<00:00, 396kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 408M/408M [00:18<00:00, 22.5MB/s]
# 100%|██████████| 1.64M/1.64M [00:05<00:00, 321kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 399M/399M [00:14<00:00, 27.8MB/s]
# 100%|██████████| 1.20M/1.20M [00:03<00:00, 339kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 401M/401M [00:16<00:00, 23.9MB/s]
# 100%|██████████| 1.60M/1.60M [00:03<00:00, 412kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 399M/399M [00:15<00:00, 26.2MB/s]
# 100%|██████████| 1.51M/1.51M [00:05<00:00, 274kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 412M/412M [00:14<00:00, 28.5MB/s]
# 100%|██████████| 409M/409M [00:14<00:00, 28.0MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.51M/1.51M [00:03<00:00, 402kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 404M/404M [00:17<00:00, 22.5MB/s]
# 100%|██████████| 1.53M/1.53M [00:03<00:00, 407kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 408M/408M [00:20<00:00, 20.3MB/s]
# 100%|██████████| 1.57M/1.57M [00:03<00:00, 431kB/s]
# ...
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 409M/409M [00:17<00:00, 23.1MB/s]
# 100%|██████████| 1.38M/1.38M [00:03<00:00, 394kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 411M/411M [00:16<00:00, 24.5MB/s]
# 100%|██████████| 1.18M/1.18M [00:03<00:00, 331kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 403M/403M [00:17<00:00, 23.1MB/s]
# 100%|██████████| 1.04M/1.04M [00:03<00:00, 301kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 412M/412M [00:16<00:00, 25.2MB/s]
# 100%|██████████| 1.52M/1.52M [00:03<00:00, 422kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 406M/406M [00:19<00:00, 21.3MB/s]
# 100%|██████████| 1.16M/1.16M [00:03<00:00, 328kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 405M/405M [00:15<00:00, 25.4MB/s]
# 100%|██████████| 428M/428M [00:22<00:00, 18.9MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.15M/1.15M [00:03<00:00, 335kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 406M/406M [00:16<00:00, 25.3MB/s]
# 100%|██████████| 367M/367M [00:15<00:00, 23.2MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 419M/419M [00:18<00:00, 22.9MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.40M/1.40M [00:04<00:00, 308kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 432M/432M [00:19<00:00, 21.9MB/s]
# 100%|██████████| 1.33M/1.33M [00:03<00:00, 370kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 397M/397M [00:15<00:00, 24.9MB/s]
# 100%|██████████| 1.19M/1.19M [00:03<00:00, 341kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 434M/434M [00:13<00:00, 31.9MB/s]
# 100%|██████████| 1.73M/1.73M [00:03<00:00, 485kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 400M/400M [00:16<00:00, 25.0MB/s]
# 100%|██████████| 395M/395M [00:15<00:00, 25.0MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 418M/418M [00:15<00:00, 27.6MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 767k/767k [00:03<00:00, 225kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 415M/415M [00:13<00:00, 31.1MB/s]
# 100%|██████████| 393M/393M [00:14<00:00, 26.8MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 370M/370M [00:16<00:00, 21.9MB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# 100%|██████████| 1.44M/1.44M [00:03<00:00, 405kB/s]
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
# /mnt/eternus/anaconda3_shared/envs/jc_im2im_dev/lib/python3.9/site-packages/ome_types/_convenience.py:105: FutureWarning: The default XML parser will be changing from 'xmlschema' to 'lxml' in version 0.4.0.  To silence this warning, please provide the `parser` argument, specifying either 'lxml' (to opt into the new behavior), or'xmlschema' (to retain the old behavior).
#   d = to_dict(os.fspath(xml), parser=parser, validate=validate)
